# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from ctadiv import *
from ctadiv.ArrayConfig import *

# %% [markdown]
# ## Load a CTA configuration

# %%
# Note that if the radius is in meters, 
# you can set LoadConfig(file, radius="meters")
# defalut is in degrees

array = LoadConfig("./Prod6/ParanalArrayPositions_divProd6.txt")

# %% [markdown]
# ## Check configuration table

# %%
array.table.units = "deg"
array.table
# Out:
# <Table length=87>
#   id     x        y       z       az   ...   p_x     p_y     p_z    d_tel
#          m        m       m      deg   ...                            m
# int64 float64  float64 float64 float64 ... float64 float64 float64 float64
# ----- -------- ------- ------- ------- ... ------- ------- ------- -------
#     1   -20.64  -64.82    34.0   0.000 ...   1.000  -0.000   0.000   67.77
#     2    79.99   -0.77    29.0   0.000 ...   1.000  -0.000   0.000   81.38
#     3    -19.4    65.2    31.0   0.000 ...   1.000  -0.000   0.000   67.59
#     4  -120.03    1.15    33.0   0.000 ...   1.000  -0.000   0.000  118.69
#     5    -0.02    -0.0    24.0   0.000 ...   1.000  -0.000   0.000    6.67
#     6     1.43  151.02    25.0   0.000 ...   1.000  -0.000   0.000  151.09
#   ...      ...     ...     ...     ... ...     ...     ...     ...     ...
#    82    953.2 -208.19    7.75   0.000 ...   1.000  -0.000   0.000  977.29
#    83   957.02  189.86    5.25   0.000 ...   1.000  -0.000   0.000  977.33
#    84 -1025.15 -510.28   59.25   0.000 ...   1.000  -0.000   0.000 1144.28
#    85 -1015.16  529.86   13.25   0.000 ...   1.000  -0.000   0.000 1144.01
#    86  1015.13 -529.86   31.25   0.000 ...   1.000  -0.000   0.000 1146.34
#    87  1025.11  510.28   25.25   0.000 ...   1.000  -0.000   0.000 1146.31

# %% [markdown]
# ## Activate the divergent pointing mode

# %%
array.divergent_pointing(div = 0.0022, az = 180, alt = 70)

#array.set_pointing_coord(az=180, alt=70)
#array.divergent_pointing(0.01)

# %% [markdown]
# ## Check the average of the telescope array location

# %%
array.calc_mean(["x", "y", "z"])
# Out:
# array([-1.37367816,  0.05862069, 30.53448276])

# %% [markdown]
# ## Check the average of the telescope pointing vector

# %%
array.calc_mean(["p_x", "p_y", "p_z"])
# Out:
# array([-3.41885283e-01,  1.04613694e-06,  9.39593307e-01])

# %% [markdown]
# ## Check the hyper field of view (hFoV)

# %%
array.hFoV(m_cut=3)
# Out:
# <Quantity 132.07061778 deg2>

# %% [markdown]
# ## Convert (radians or meters) to degrees

# %%
array.table.units = "deg"
array.table
# Out:
# <Table length=87>
#   id     x        y       z       az   ...   p_x     p_y     p_z    d_tel
#          m        m       m      deg   ...                            m
# int64 float64  float64 float64 float64 ... float64 float64 float64 float64
# ----- -------- ------- ------- ------- ... ------- ------- ------- -------
#     1   -20.64  -64.82    34.0 179.761 ...  -0.342  -0.001   0.940   67.77
#     2    79.99   -0.77    29.0 179.997 ...  -0.340  -0.000   0.940   81.38
#     3    -19.4    65.2    31.0 180.240 ...  -0.342   0.001   0.940   67.59
#     4  -120.03    1.15    33.0 180.004 ...  -0.344   0.000   0.939  118.69
#     5    -0.02    -0.0    24.0 180.000 ...  -0.342  -0.000   0.940    6.67
#     6     1.43  151.02    25.0 180.556 ...  -0.342   0.003   0.940  151.09
#   ...      ...     ...     ...     ... ...     ...     ...     ...     ...
#    82    953.2 -208.19    7.75 179.182 ...  -0.323  -0.005   0.946  977.29
#    83   957.02  189.86    5.25 180.745 ...  -0.323   0.004   0.946  977.33
#    84 -1025.15 -510.28   59.25 178.236 ...  -0.361  -0.011   0.932 1144.28
#    85 -1015.16  529.86   13.25 181.832 ...  -0.362   0.012   0.932 1144.01
#    86  1015.13 -529.86   31.25 177.911 ...  -0.322  -0.012   0.947 1146.34
#    87  1025.11  510.28   25.25 182.013 ...  -0.322   0.011   0.947 1146.31

# %% [markdown]
# ## Check the ICRS coordinate of the pointing

# %%
array.frame.info
array.get_pointing_coord(icrs=True)
# Out:
# Observer         :  CTA North
# Location         :  Roque de los Muchachos , (5327.1607829, -1718.7370058, 3051.71504125) km
# Observation time :  2022-11-11T15:05:50.718
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(259.13671746,  8.76270643), (259.05531031,  8.87998411),
#      (258.97092767,  8.7632391 ), (259.0523413 ,  8.64487184),
#      (259.05411226,  8.78300173), (258.86147737,  8.78551874),
#      (259.24672576,  8.78383631), (258.96050282,  8.96067906),
#      (259.15217883,  8.9606934 ), (258.74967238,  8.96419441),
#      (259.36297417,  8.9599581 ), (259.0587727 ,  9.15257017),
#      (259.14740776,  8.60616047), (258.95636856,  8.60827496),
#      (259.3574864 ,  8.60829021), (258.74621634,  8.61006487),
#      (259.25541899,  8.41554804), (258.84351903,  8.41813232),
#      (259.46860815,  8.78464897), (258.63949213,  8.7873689 ),
#      (259.26613821,  9.15382364), (258.85138525,  9.15481933),
#      (259.63413096,  9.12783064), (258.48257018,  9.13487803),
#      (259.04948462,  8.41546541), (258.47740908,  8.44185203),
#      (259.6217718 ,  8.44449773), (259.06281817,  9.4711249 ),
#      (259.0455329 ,  8.10184152), (258.63886432,  9.28172138),
#      (259.47011558,  9.280852  ), (258.64051903,  8.31066583),
#      (259.46449708,  8.3097897 ), (259.57377823,  8.95857885),
#      (258.53372153,  8.96060313), (259.57158   ,  8.60909661),
#      (258.53480771,  8.6111149 ), (259.05707082,  9.01581151),
#      (259.0506962 ,  8.51044092), (259.4637884 ,  8.49107823),
#      (258.63684213,  8.48997062), (259.78407998,  8.49295191),
#      (258.31602389,  8.48912092), (260.06420784,  8.5295338 ),
#      (258.03620255,  8.52670356), (259.69047059,  8.7822072 ),
#      (258.41733879,  8.78423849), (260.00880017,  8.78770245),
#      (258.09836864,  8.78753465), (259.4735011 ,  9.07509663),
#      (258.64202947,  9.07985164), (259.79558063,  9.07697538),
#      (258.31964369,  9.08333813), (260.07575313,  9.0451156 ),
#      (258.03825516,  9.05450606), (259.21168052,  8.19540286),
#      (258.88177996,  8.1977142 ), (259.67948971,  8.20213501),
#      (258.41332587,  8.19448415), (260.06664925,  8.24332898),
#      (258.02649667,  8.2398734 ), (259.22834141,  9.36956049),
#      (258.89476902,  9.37201092), (259.70146118,  9.37133784),
#      (258.42135503,  9.37715502), (260.09113272,  9.33682343),
#      (258.0305296 ,  9.35256083), (259.04245946,  7.85430742),
#      (258.57852679,  7.90369437), (259.50728703,  7.9099855 ),
#      (258.22232898,  7.82315439), (259.86073126,  7.83376396),
#      (259.06594315,  9.71628215), (259.53744863,  9.66035654),
#      (258.59315474,  9.67170487), (259.89994131,  9.75247393),
#      (258.23227483,  9.76173382), (257.84230884,  8.79632413),
#      (260.26460293,  8.78974296), (259.29129326,  7.66383092),
#      (258.78874833,  7.66192381), (259.32502024,  9.91284125),
#      (258.81185058,  9.91753486), (259.69485427,  7.59217366),
#      (258.38274211,  7.58582541), (259.74000772,  9.99542051),
#      (258.3987332 , 10.00792265)]>

# %% [markdown]
# ## Grouping telescopes

# %%
group = {"LST": [1,2,3,4],
        "MST": np.arange(5, 20)}

sub_groups={'1': [5,17,18], 
            '2': [10,11,14],
            '3': [7,15,8], 
            '4': [9,13,19],
            '5': [6,12,16],
            'LST': [1,2,3,4]}

array.display("xz", group=group)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ### Subarray barycenter

# %%
from ctadiv.ArrayConfig import visualization as visual

# %%
groupped_table, labels = array.group_by(sub_groups)
visual.display_barycenter(groupped_table, proj="xz", labels=labels)
# Out:
# <img src="data:image/png;base64,..." width="800">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# ## Export cfg file

# %%
#array.export_cfg(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 array.export_cfg(verbose=True)
#
# TypeError: Array.export_cfg() missing 3 required positional arguments: 'LST_config', 'MST_config', and 'SST_config'

# %% [markdown]
# ## Display the telescope pointing

# %% [markdown]
# ### Simple display

# %%
# 1D
array.display("y")

# %%
# 2D
array.display("xz", group=group)

# %%
# 3D
array.display("xyz", group=group)

# %%
# Skymap
array.display(skymap=True,projection='x')

# %%
# Multiplicity plot
array.multiplicity_plot()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Multiplicity plot
array.skymap_polar()
# Out:
# <img src="data:image/png;base64,..." width="800">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Advanced display

# %% [markdown]
# ### Interactive

# %%
from ctadiv.ArrayConfig.visualization import *

# %%
new_array = interactive_polar(array, group=group, overwrite=False)

# %%
interactive_multiplicity(array, overwrite=True)

# %%
interactive_barycenter(array, "xy", group=sub_groups)
